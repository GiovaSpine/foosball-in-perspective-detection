# %% [markdown]
# # Data Analysis
# This notebook shows the analysis of the data:

# %%
import sys
from pathlib import Path
from IPython.display import Markdown, display
sys.path.append(str(Path("../src").resolve()))
from config import MAX_N_CLUSTERS

display(Markdown(f"## Max number of clusters: {MAX_N_CLUSTERS}"))
# Out:
# ## Max number of clusters: 50

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4, 5]
y = [n**2 for n in x]

plt.plot(x, y, marker='o')
plt.title("Example")
plt.xlabel("x")
plt.ylabel("y = x^2")
plt.show()
